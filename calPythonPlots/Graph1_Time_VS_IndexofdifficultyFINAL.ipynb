# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
from pylab import polyfit, poly1d
import pandas as pd
from ipykernel import kernelapp as app

# %%
df = pd.read_csv('C:\\Users\\Khushbu\\Downloads\\dm1.csv');
df
# Out:
#      Time  IndexOfDiff  Distance  Width
# 0    1112     3.510962       208     20
# 1     965     3.510962       208     20
# 2     759     3.510962       208     20
# 3     666     3.510962       208     20
# 4     619     3.510962       208     20
# 5     911     3.510962       208     20
# 6     671     3.510962       208     20
# 7     530     3.510962       208     20
# 8    1112     3.510962       250     20
# 9     965     3.510962       250     20
# 10    759     3.510962       250     20
# 11    666     3.510962       250     20
# 12    619     3.510962       250     20
# 13    911     3.510962       250     20
# 14    671     3.510962       250     20
# 15    530     3.510962       250     20
# 16    796     3.754888       250     20
# 17    839     3.754888       250     20
# 18   1003     3.754888       250     20
# 19    727     3.754888       250     20
# 20    735     3.754888       250     20
# 21    881     3.754888       250     20
# ...

# %%
df200_20 = df.query('Distance == 208 and Width == 20')
df200_50 = df.query('Distance == 208 and Width == 50')
df300_20 = df.query('Distance == 300 and Width == 20')
df300_50 = df.query('Distance == 300 and Width == 50')
df250_20 = df.query('Distance == 250 and Width == 20')
df250_50 = df.query('Distance == 250 and Width == 50')

# %%
mean200_20 = df200_20["Time"].mean() #ide = 3.510962	
mean200_50 = df200_50["Time"].mean() #3.510961919
mean300_20 = df300_20["Time"].mean()  #3.754887502
mean300_50 = df300_50["Time"].mean() #ide = 3.459432
mean250_20 = df250_20["Time"].mean() #3.510962	
mean250_50 = df250_50["Time"].mean()



ideMean_200_20 = df200_20["IndexOfDiff"].mean()
ideMean_200_50 = df200_50["IndexOfDiff"].mean()
ideMean_300_20 = df300_20["IndexOfDiff"].mean()
ideMean_300_50 = df300_50["IndexOfDiff"].mean()
ideMean_250_20 = df250_20["IndexOfDiff"].mean()
ideMean_250_50 = df250_50["IndexOfDiff"].mean()

x = pd.DataFrame()
y = pd.DataFrame()

y['Time'] = [mean200_20, mean200_50, mean300_20, mean300_50, mean250_20, mean250_20]

x['IndexOfD'] = [ideMean_200_20, ideMean_200_50, ideMean_300_20, ideMean_300_50, ideMean_250_20, ideMean_250_50]

# %%
x
# Out:
#    IndexOfD
# 0  3.510962
# 1  3.215327
# 2  3.765496
# 3  3.549142
# 4  3.624794
# 5  3.371530

# %%
y = df[['Time']];
x = df[['IndexOfDiff']];
#colors = np.random.rand(50);

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


regr = linear_model.LinearRegression()
regr.fit(x, y);

y_pred = regr.predict(x);

plt.scatter(x, y)
plt.plot(x, y_pred, linewidth=3)

plt.xlabel('Mean Index of Difficulty', fontsize=16)
plt.ylabel('Mean Time in ms', fontsize=16)
plt.show()

# %%
print('Coefficients: \n', regr.coef_)
# Out:
# ('Coefficients: \n', array([[ 139.47063068]]))

# %%
y = df[['Time']];
#colors = np.random.rand(50);

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


regr = linear_model.LinearRegression()
regr.fit(x, y);

y_pred = regr.predict(x);

plt.scatter(x, y)
plt.xlabel('Index of Difficulty', fontsize=16)
plt.ylabel('Time in ms', fontsize=16)
plt.plot(x, y_pred, linewidth=3)
plt.show()

# %%
df = pd.read_csv('C:\\Users\\Khushbu\\Downloads\\dm2.csv');
df
# Out:
#      Time  IndexOfDiff  Distance  Width
# 0     616     3.510962       208     20
# 1     715     3.510962       208     20
# 2     940     3.510962       208     20
# 3     662     3.510962       208     20
# 4     650     3.510962       208     20
# 5     752     3.510962       208     20
# 6     926     3.510962       208     20
# 7     616     3.510962       250     20
# 8     715     3.510962       250     20
# 9     940     3.510962       250     20
# 10    662     3.510962       250     20
# 11    650     3.510962       250     20
# 12    752     3.510962       250     20
# 13    926     3.510962       250     20
# 14    858     3.754888       250     20
# 15    919     3.754888       250     20
# 16    901     3.754888       250     20
# 17    667     3.754888       250     20
# 18    804     3.754888       250     20
# 19    762     3.754888       250     20
# 20    616     3.510962       300     20
# 21    715     3.510962       300     20
# ...

# %%
y1 = df[['Time']];
x1 = df[['IndexOfDiff']];
#colors = np.random.rand(50);

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


regr = linear_model.LinearRegression()
regr.fit(x1, y1);

y_pred1 = regr.predict(x1);

plt.scatter(x1, y1)
plt.xlabel('Index of Difficulty', fontsize=16)
plt.ylabel('Time in ms', fontsize=16)
plt.plot(x1, y_pred1, linewidth=3)
plt.show()

y_pred1.size
# Out:
# 6

# %%
x1.size
# Out:
# 224

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(x, y, s=10, c='b', marker="s", label='User1')
ax1.scatter(x1,y1, s=10, c='r', marker="o", label='User2')


regr1 = linear_model.LinearRegression()
regr2 = linear_model.LinearRegression()
regr1.fit(x1, y1);
regr.fit(x,y);

y_pred1 = regr1.predict(x1);
y_pred = regr.predict(x);

plt.plot(x1, y_pred1, linewidth=3)
plt.plot(x, y_pred, linewidth=3)

plt.xlabel('Mean Index of Difficulty', fontsize=16)
plt.ylabel('Mean Time in ms', fontsize=16)




plt.legend(loc='upper left');
plt.show()

# %%
df200_20 = df.query('Distance == 208 and Width == 20')
df200_50 = df.query('Distance == 208 and Width == 50')
df300_20 = df.query('Distance == 300 and Width == 20')
df300_50 = df.query('Distance == 300 and Width == 50')
df250_20 = df.query('Distance == 250 and Width == 20')
df250_50 = df.query('Distance == 250 and Width == 50')

# %%
mean200_20 = df200_20["Time"].mean() #ide = 3.510962	
mean200_50 = df200_50["Time"].mean() #3.510961919
mean300_20 = df300_20["Time"].mean()  #3.754887502
mean300_50 = df300_50["Time"].mean() #ide = 3.459432
mean250_20 = df250_20["Time"].mean() #3.510962	
mean250_50 = df250_50["Time"].mean()



ideMean_200_20 = df200_20["IndexOfDiff"].mean()
ideMean_200_50 = df200_50["IndexOfDiff"].mean()
ideMean_300_20 = df300_20["IndexOfDiff"].mean()
ideMean_300_50 = df300_50["IndexOfDiff"].mean()
ideMean_250_20 = df250_20["IndexOfDiff"].mean()
ideMean_250_50 = df250_50["IndexOfDiff"].mean()

x1 = pd.DataFrame()
y1 = pd.DataFrame()

#y1['Time'] = [mean200_50, mean200_20, mean300_20, mean300_50, mean250_20, mean250_20]


y1['Time'] = [mean200_20, mean200_50,mean300_20, mean300_50, mean250_20, mean250_20]
x1['IndexOfD'] = [ideMean_200_20, ideMean_200_50, ideMean_300_20, ideMean_300_50, ideMean_250_20, ideMean_250_50]

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


regr = linear_model.LinearRegression()
regr.fit(x1, y1);

y_pred1 = regr.predict(x1);

plt.scatter(x1, y1)
plt.xlabel('Index of Difficulty', fontsize=16)
plt.ylabel('Time in ms', fontsize=16)
plt.plot(x1, y_pred1, linewidth=3)
plt.show()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

fig = plt.figure()
ax1 = fig.add_subplot(111)

ax1.scatter(x, y, s=10, c='b', marker="s", label='User1')
ax1.scatter(x,y1, s=10, c='r', marker="o", label='User2')


regr1 = linear_model.LinearRegression()
regr = linear_model.LinearRegression()
regr1.fit(x, y1);
regr.fit(x,y);

y_pred1 = regr1.predict(x);
y_pred = regr.predict(x);

plt.plot(x, y_pred1, linewidth=3)
plt.plot(x, y_pred, linewidth=3)

plt.xlabel('Mean Index of Difficulty', fontsize=16)
plt.ylabel('Mean Time in ms', fontsize=16)




plt.legend(loc='upper left');
plt.show()

# %%
print('Coefficients: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# ('Coefficients: \n', array([ 24.44235066]))
# ('Coefficients: \n', array([[ 212.5846103]]))

# %%
print('Coefficients: \n', regr1.intercept_)
print('Coefficients: \n', regr1.coef_)
# Out:
# ('Coefficients: \n', array([-69.73759392]))
# ('Coefficients: \n', array([[ 260.16688584]]))

# %%
print('Coefficients: \n', regr1.intercept_)
# Out:
# ('Coefficients: \n', array([-69.73759392]))

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score


regr = linear_model.LinearRegression()
regr.fit(x1, y1);

y_pred1 = regr.predict(x1);

plt.scatter(x1, y1)
plt.plot(x1, y_pred1, linewidth=3)

plt.xlabel('Mean Index of Difficulty', fontsize=16)
plt.ylabel('Mean Time in ms', fontsize=16)
plt.show()
